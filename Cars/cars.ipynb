# %%
import pandas as pd

# %%
df = pd.read_csv("./auto-mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.title("mpg")
plt.xlabel("mpg")
df["mpg"].plot.hist()
# Out:
# <AxesSubplot:title={'center':'mpg'}, xlabel='mpg', ylabel='Frequency'>

# %%
plt.title("cylinders")
plt.xlabel("cylinders")
df["cylinders"].plot.hist()
# Out:
# <AxesSubplot:title={'center':'cylinders'}, xlabel='cylinders', ylabel='Frequency'>

# %%
plt.title("displacement")
plt.xlabel("displacement")
df["displacement"].plot.hist()
# Out:
# <AxesSubplot:title={'center':'displacement'}, xlabel='displacement', ylabel='Frequency'>

# %%
import numpy as np

df["horsepower"].replace("?",np.NaN, inplace=True)
df["horsepower"] = pd.to_numeric(df["horsepower"])
df[pd.isnull(df["horsepower"])]

plt.title("horsepower")
plt.xlabel("horsepower")
df["horsepower"].plot.hist()
# Out:
# <AxesSubplot:title={'center':'horsepower'}, xlabel='horsepower', ylabel='Frequency'>

# %%
plt.title("weight")
plt.xlabel("weight")
df["weight"].plot.hist()
# Out:
# <AxesSubplot:title={'center':'weight'}, xlabel='weight', ylabel='Frequency'>

# %%
plt.title("acceleration")
plt.xlabel("acceleration")
df["acceleration"].plot.hist()
# Out:
# <AxesSubplot:title={'center':'acceleration'}, xlabel='acceleration', ylabel='Frequency'>

# %%
plt.title("model year")
plt.xlabel("model year")
df["model year"].plot.hist()
# Out:
# <AxesSubplot:title={'center':'model year'}, xlabel='model year', ylabel='Frequency'>

# %%
plt.title("origin")
plt.xlabel("origin")
df["origin"].plot.hist()
# Out:
# <AxesSubplot:title={'center':'origin'}, xlabel='origin', ylabel='Frequency'>

# %%
plt.title("car name")
plt.xlabel("car name")
count = df["car name"].value_counts()
count.plot.bar()
# Out:
# <AxesSubplot:title={'center':'car name'}, xlabel='car name'>

# %%
 df["car name"].value_counts()
# Out:
# ford pinto             6
# amc matador            5
# ford maverick          5
# toyota corolla         5
# toyota corona          4
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevy s-10             1
# Name: car name, Length: 304, dtype: int64

# %%
import seaborn as sns
sns.boxplot(data=df["mpg"], width=0.5)
a = df[df["mpg"] > 45].index
df.drop(a, inplace=True)
df.iloc[a]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model year, origin, car name]
# Index: []

# %%
plt.title("mpg")
plt.xlabel("mpg")
plt.ylabel("cylinders")
plt.plot(df["mpg"], df["model year"], 'ro')

# %%
plt.title("mpg")
plt.xlabel("mpg")
plt.ylabel("cylinders")
plt.plot(df["mpg"], df["origin"], 'ro')

# %%
df["brand"] = df["car name"].str.split()[:].str[0]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df["labels"]= encoder.fit_transform(df["brand"])
df["labels"]

plt.title("mpg")
plt.xlabel("mpg")
plt.ylabel("labels")
plt.plot(df["mpg"], df["labels"], 'ro')

# %%
df["brand"].value_counts()
# Out:
# ford             51
# chevrolet        43
# plymouth         31
# amc              28
# dodge            28
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# oldsmobile       10
# mazda             9
# fiat              8
# peugeot           8
# audi              7
# chrysler          6
# vw                6
# volvo             6
# renault           5
# saab              4
# subaru            4
# opel              4
# chevy             3
# bmw               2
# cadillac          2
# maxda             2
# mercedes-benz     2
# triumph           1
# vokswagen         1
# mercedes          1
# hi                1
# capri             1
# chevroelt         1
# toyouta           1
# nissan            1
# Name: brand, dtype: int64

# %%
plt.title("mpg")
plt.xlabel("mpg")
plt.ylabel("labels")
plt.plot(df["mpg"], df["acceleration"], 'ro')

# %%
plt.title("mpg")
plt.xlabel("mpg")
plt.ylabel("labels")
plt.plot(df["mpg"], df["weight"], 'ro')

# %%
plt.title("mpg")
plt.xlabel("mpg")
plt.ylabel("labels")
plt.plot(df["mpg"], df["horsepower"], 'ro')

# %%
plt.title("mpg")
plt.xlabel("mpg")
plt.ylabel("labels")
plt.plot(df["mpg"], df["displacement"], 'ro')

# %%
plt.title("mpg")
plt.xlabel("mpg")
plt.ylabel("labels")
plt.plot(df["mpg"], df["model year"], 'ro')

# %%
##critics
#write your comments on each visualization
#when values are too much, its better to display a values count
